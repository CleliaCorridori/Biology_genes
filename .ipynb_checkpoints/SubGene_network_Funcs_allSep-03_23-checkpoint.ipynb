# %% [markdown]
# # Network of Subset of genes
#
# 03/22/2022
#
# Clelia Corridori

# %% [markdown]
# Considering all data together

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib.colors import LogNorm
import matplotlib
import numpy.linalg as la

import sys
sys.path.append('../')

import funcs as funcs
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## DATA

# %%
path = "C:/Users/cleli/OneDrive - Università degli Studi di Padova/LAVORO/GeneNetwork/"
file_name = "geni_IMP.xlsx"
df = pd.read_excel(path + file_name)
df
# Out:
#          EnsemblGeneID   Symbol    GM_2iL_2    GM_2iL_1  GM_24h_2iL_2  \
# 0   ENSMUSG00000003032     Klf4  721.246075  790.448527    362.034812
# 1   ENSMUSG00000055148     Klf2  300.890974  288.413501    124.602767
# 2   ENSMUSG00000021255    Esrrb  179.939742  201.400614    103.999160
# 3   ENSMUSG00000026380  Tfcp2l1  797.584148  796.803401    135.395133
# 4   ENSMUSG00000018604     Tbx3  212.656059  258.105641    129.508388
# 5   ENSMUSG00000004040    Stat3  104.593073  110.477036    100.074664
# 6   ENSMUSG00000055799   Tcf7l1  214.143165  222.420581    311.016356
# 7   ENSMUSG00000012396    Nanog  172.999918  155.938825     66.716442
# 8   ENSMUSG00000027547    Sall4  158.624566  155.449989    259.997900
# 9   ENSMUSG00000024406   Pou5f1   72.372458   76.258485     62.791946
# 10  ENSMUSG00000074637     Sox2  784.695902  693.170075    512.146808
# 11  ENSMUSG00000020661   Dnmt3a   38.169036   41.062261    103.018036
# 12  ENSMUSG00000027478   Dnmt3b   67.911142   71.370121    351.242447
# 13  ENSMUSG00000047751     Utf1   16.853860   10.265565    152.074244
# 14  ENSMUSG00000021848     Otx2   57.005704   50.350154    143.244126
# 15  ENSMUSG00000013089     Etv5  245.372376  231.708474    145.206375
# 16  ENSMUSG00000017724     Etv4   30.237808   29.330187     45.131711
# 17  ENSMUSG00000025056    Nr0b1    8.426930   13.198584     38.263842
# 18  ENSMUSG00000067860     Zic3   62.954125   62.082228    122.640519
# 19  ENSMUSG00000027985     Lef1   12.888246   14.665093     23.546980
# 20  ENSMUSG00000068079    Tcf15    3.965614    9.776729     21.584731
# 21  ENSMUSG00000034486     Gbx2    7.931228   12.709747      7.848993
# 22  ENSMUSG00000090125   Pou3f1    2.478509    1.955346     28.452600
# 23  ENSMUSG00000039191     Rbpj   42.134650   50.350154    153.055368
#
#     GM_24h_2iL_1  GM_36h_2iL_2  GM_36h_2iL_1  GM_48h_2iL_2  GM_48h_2iL_1  ...  \
# 0     507.580169    338.426474    275.595044    109.118435    141.201368  ...
# 1     102.125740     87.270395     86.229124     51.552016     27.900029  ...
# 2      83.834562     47.694286     52.413781     24.916808     11.228061  ...
# 3     111.271328     69.511885     70.166836     22.339207     18.713434  ...
# 4     110.509196     19.788055     30.011117      6.873602      4.423175  ...
# 5      74.688974     64.438024     70.589528     56.707218     26.879297  ...
# 6     241.595966    190.269757    213.882044    190.312861    154.130650  ...
# 7      45.727943     31.965319     23.670740     10.740003      6.124397  ...
# 8     187.484567    207.013495    222.758571    230.695273    224.561212  ...
# 9     113.557725    111.117538     93.837576     76.039224    121.807446  ...
# 10    522.822816    593.641641    467.497115    400.816928    377.330886  ...
# 11    147.091550    425.696869    379.154532    780.583449    675.384859  ...
# 13    44.570377     7.870304     7.381320     4.913884     3.168726
# 14   118.854339    11.805456    17.530635    12.284710    12.041160
# 15   101.620460    48.795883    59.050559    39.311073    23.448576
# 16    24.959411    20.462790    22.143960    15.560633     8.872434
# 17     0.594272     0.000000     0.000000     0.000000     0.000000
# 18   158.670543   177.081833   175.306348   120.390162   119.144114
# 19   108.751720    73.980855    79.349189    65.518456    72.880708
# 20     2.971358     2.361091     2.767995     1.637961     0.000000
# 21    48.730279    49.582913    39.674595    20.474517    18.378613
# 22   237.708679   128.285950   124.559773    68.794379    95.695539
# 23    33.873487    42.499640    48.901244    54.052726    38.024717
#
# [24 rows x 34 columns]

# %%
col_names = np.array(df.columns)
# print(col_names)

col_names_2iL_1 = [col_names[3+2*i] for i in range(8)]
print(col_names_2iL_1)

col_names_2iL_2 = [col_names[2+2*i] for i in range(8)]
print(col_names_2iL_2)

col_names_2i_1 = [col_names[18+2*i] for i in range(8)]
print(col_names_2i_1)

col_names_2i_2 = [col_names[19+2*i] for i in range(8)]
print(col_names_2i_2)
# Out:
# ['GM_2iL_1', 'GM_24h_2iL_1', 'GM_36h_2iL_1', 'GM_48h_2iL_1', 'GM_60h_2iL_1', 'GM_72h_2iL_1', 'GM_84h_2iL_1', 'GM_96h_2iL_1']
# ['GM_2iL_2', 'GM_24h_2iL_2', 'GM_36h_2iL_2', 'GM_48h_2iL_2', 'GM_60h_2iL_2', 'GM_72h_2iL_2', 'GM_84h_2iL_2', 'GM_96h_2iL_2']
# ['GM_2i_1', 'GM_12h_2i_1', 'GM_24h_2i_1', 'GM_36h_2i_1', 'GM_48h_2i_1', 'GM_60h_2i_1', 'GM_72h_2i_1', 'GM_84h_2i_1']
# ['GM_2i_2', 'GM_12h_2i_2', 'GM_24h_2i_2', 'GM_36h_2i_2', 'GM_48h_2i_2', 'GM_60h_2i_2', 'GM_72h_2i_2', 'GM_84h_2i_2']

# %%
df_2iL_1 = np.array(df.loc[:, col_names_2iL_1])
print("[# gene x # samples], set_1_2iL", df_2iL_1.shape)
df_2iL_2 = np.array(df.loc[:, col_names_2iL_2] )
print("[# gene x # samples], set_2_2iL", df_2iL_2.shape)
df_2iL = np.concatenate((df_2iL_1,df_2iL_2), 1)
print("[# gene x # samples], set_all_2iL", df_2iL.shape)

df_2i_1 = np.array(df.loc[:, col_names_2i_1])
print("[# gene x # samples], set_1_2i", df_2iL_1.shape)
df_2i_2 = np.array(df.loc[:, col_names_2i_2] )
print("[# gene x # samples], set_2_2i", df_2iL_2.shape)
df_2i = np.concatenate((df_2i_1,df_2i_2), 1)
print("[# gene x # samples], set_all_2i", df_2i.shape)
# Out:
# [# gene x # samples], set_1_2iL (24, 8)
# [# gene x # samples], set_2_2iL (24, 8)
# [# gene x # samples], set_all_2iL (24, 16)
# [# gene x # samples], set_1_2i (24, 8)
# [# gene x # samples], set_2_2i (24, 8)
# [# gene x # samples], set_all_2i (24, 16)

# %% [markdown]
# ## PEARSON CORRELATION COEFFICIENTS

# %%
C_Mean_2i = funcs.Pearson_info(df_2i, det=True)
C_Mean_2iL = funcs.Pearson_info(df_2iL, det=True)
C_Mean = (C_Mean_2i+C_Mean_2iL)/2

genes = np.array(df["Symbol"])
funcs.fig_matx(C_Mean_2i, genes, "2i")
funcs.fig_matx(C_Mean_2iL, genes, "2i+LIF")
funcs.fig_matx(C_Mean, genes, "Average between 2i and 2i+LIF")
# Out:
# determinant:  -6.832879005168959e-153 6
# determinant:  1.725952331663888e-152 6

# %%
# distribution of correlation coefficient
counts_2i, bins_2i, patches_2i, __ = funcs.fig_distribution(C_Mean_2i, "2i")
counts_2iL,  bins_2iL, patches_2iL, __ = funcs.fig_distribution(C_Mean_2i, "2i+LIF")

counts, bins, patches, __ = funcs.fig_distribution(C_Mean, "all data")

# %% [markdown]
# ## MATRICES OF THE INTERACTIONS

# %% [markdown]
# ### With Spectral Decomposition

# %%
# np.fill_diagonal(C_Mean, 0)

THR = 0.001

eigval, eigvect = funcs.eigval_analysis(C_Mean, thr = THR, info=False, fig=False)
# print(eigval[-2:])


# check
print("original determinant", la.det(np.diag(eigval)))
print("determinant with cut eigenvalues", la.det(np.diag(eigval[:15])))
print(eigval[14])
# Out:
# original determinant 1.9039905220953926e-27
# determinant with cut eigenvalues 1.5200770666075089e-06
# 0.04075496919726142

# %%
#pseudo inverse
Mint = -np.linalg.pinv(C_Mean, rcond=0.05/np.max(eigval))
# print("check (differences between pseudo-inverse and inverse matrices' elements)", len(Mint[Mint-la.inv(C_Mean)>0.001]))
# print("check (differences between pseudo-inverse and inverse matrices' elements)", len(Mint[Mint-MintP>0.001]))

# figures 
perc = 0.1
level = np.max(Mint)*perc #5%
print("level of the cut-off", level, str(perc*100)+"% of ", np.max(Mint))
funcs.fig_matx_int(Mint, genes, "all", thr = level, lintsh = 0.1)

# Info
rows, cols = funcs.ind_val_abs(Mint, 10, False)
gene_names = funcs.gene_list(rows, cols, genes)
print("The ten strongest interactions: \n", gene_names)
# Out:
# level of the cut-off 0.3582738583675904 10.0% of  3.5827385836759036
# C:\Users\cleli\Biology_genes\funcs.py:95: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("coolwarm"))
#   cmap.set_bad(color='white')
# C:\Users\cleli\Biology_genes\funcs.py:98: MatplotlibDeprecationWarning: default base will change from np.e to 10 in 3.4.  To suppress this warning specify the base keyword argument.
#   plt.imshow(masked_array, norm=colors.SymLogNorm(lintsh), cmap=cmap)
# The ten strongest interactions:
#  [['Dnmt3a', 'Tbx3'], ['Tbx3', 'Dnmt3a'], ['Nr0b1', 'Tcf15'], ['Tcf15', 'Nr0b1'], ['Zic3', 'Rbpj'], ['Rbpj', 'Zic3'], ['Zic3', 'Lef1'], ['Lef1', 'Zic3'], ['Pou5f1', 'Utf1'], ['Utf1', 'Pou5f1']]

# %%
# distribution of interaction coefficients
int_vect = np.squeeze(np.reshape(Mint, (np.shape(Mint)[0]*np.shape(Mint)[1],1)))
# int_vect_2i = np.squeeze(np.reshape(Interac_matx_2i, (np.shape(Interac_matx_2i)[0]*np.shape(Interac_matx_2i)[1],1)))

plt.figure(figsize=(12,6))
plt.hist(int_vect, 30, density=False, color="Navy")
plt.grid()
plt.title("2i+LIF", fontsize=14)
plt.xlabel("Interaction Coefficients", fontsize=14)
plt.ylabel("Counts", fontsize=14)
thresh = level
plt.axvline(thresh, color="red", label="+"+np.str(thresh) )
plt.axvline(-thresh, color="red", label="-"+np.str(thresh) )
plt.legend(fontsize="14")
# plt.xscale("log")
